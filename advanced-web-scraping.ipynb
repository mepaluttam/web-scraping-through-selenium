# %%
with open('smartprix.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
soup = BeautifulSoup(html,'lxml')

# %%
containers = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in containers:
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(names)
# Out:
# 1020

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                      model    price rating  \
# 0              OPPO A59 5G  ₹14,999     71
# 1      Xiaomi Redmi 13C 5G  ₹10,999     74
# 2     Motorola Edge 40 Neo  ₹22,999     84
# 3     Motorola Moto G54 5G  ₹13,999     84
# 4     OnePlus Nord CE 3 5G  ₹24,679     84
# ...                    ...      ...    ...
# 1015        Lvix L1 Cruise     ₹899    NaN
# 1016                MTR F1   ₹1,200    NaN
# 1017               MTR Pro     ₹748    NaN
# 1018        GFive Rock New     ₹695    NaN
# 1019       Good One Bullet   ₹1,289    NaN
#
#                                                     sim  \
# 0                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# ...                                                 ...
# 1015                                           Dual Sim
# 1016                                           Dual Sim
# 1017                                           Dual Sim
# 1018                                           Dual Sim
# 1019                                           Dual Sim
#
#                                               processor  \
# 0          Dimensity 6020, Octa Core, 2.2 GHz Processor
# 1     Dimensity 6100 Plus, Octa Core, 2.2 GHz Processor
# 2          Dimensity 7030, Octa Core, 2.5 GHz Processor
# 3          Dimensity 7020, Octa Core, 2.2 GHz Processor
# 4        Snapdragon  782G, Octa Core, 2.7 GHz Processor
# ...                                                 ...
# 1015                                 1.77 MHz Processor
# 1016                                 1.41 MHz Processor
# 1017                                 1.41 MHz Processor
# 1018                                  770 kHz Processor
# 1019                                  1.2 MHz Processor
#
#                            ram                                  battery  \
# 0     4 GB RAM, 128 GB inbuilt  5000 mAh Battery with 33W Fast Charging
# 1     4 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 2     8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68W Fast Charging
# 3     8 GB RAM, 128 GB inbuilt  6000 mAh Battery with 33W Fast Charging
# 4     8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 80W Fast Charging
# ...                        ...                                      ...
# 1015  16 MB RAM, 32 MB inbuilt                         3000 mAh Battery
# 1016  32 MB RAM, 32 MB inbuilt                         1100 mAh Battery
# 1017  32 MB RAM, 32 MB inbuilt                         1100 mAh Battery
# 1018  12 MB RAM, 32 MB inbuilt                         1050 mAh Battery
# 1019  32 MB RAM, 32 MB inbuilt                         2500 mAh Battery
#
#                                                 display  \
# 0     6.56 inches, 720 x 1612 px, 90 Hz Display with...
# 1     6.74 inches, 720 x 1600 px, 90 Hz Display with...
# 2     6.55 inches, 1080 x 2400 px, 144 Hz Display wi...
# 3     6.5 inches, 1080 x 2400 px, 120 Hz Display wit...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015                   2.4 inches, 320 x 240 px Display
# 1016                  1.77 inches, 120 x 240 px Display
# 1017                  1.77 inches, 120 x 240 px Display
# 1018                   1.8 inches, 160 x 128 px Display
# 1019                   2.4 inches, 320 x 240 px Display
#
#                                                  camera  \
# 0            13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 1     50 MP + Depth Sensor Dual Rear & 5 MP Front Ca...
# 2          50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 3           50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 4     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# ...                                                 ...
# 1015                                 0.3 MP Rear Camera
# 1016                                 0.3 MP Rear Camera
# 1017                                 0.3 MP Rear Camera
# 1018                                 0.3 MP Rear Camera
# 1019                                   2 MP Rear Camera
#
#                                    card           os
# 0      Memory Card Supported, upto 1 TB  Android v13
# 1      Memory Card Supported, upto 1 TB  Android v13
# 2             Memory Card Not Supported  Android v13
# 3       Memory Card (Hybrid), upto 1 TB  Android v13
# 4       Memory Card (Hybrid), upto 1 TB  Android v13
# ...                                 ...          ...
# 1015  Memory Card Supported, upto 16 GB    Bluetooth
# 1016                        No FM Radio          NaN
# 1017                        No FM Radio          NaN
# 1018  Memory Card Supported, upto 16 GB    Bluetooth
# 1019  Memory Card Supported, upto 32 GB          NaN
#
# [1020 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     785 non-null    object
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1018 non-null   object
#  9   card       1000 non-null   object
#  10  os         957 non-null    object
# dtypes: object(11)
# memory usage: 87.8+ KB

# %%
df.to_csv('smartphones.csv', index=False)

# %%
df.to_excel('smartphones.xlsx', index=False)
